# %% [markdown]
# # Inception v4
# **1. Inception-A block:**
# - Using two 3x3 convolutions instead of 5x5 convolutions, and using average pooling, this module mainly deals with a 35x35 feature map; the structure is as follows:
# ![Screenshot%202021-06-24%20013322.png](attachment:Screenshot%202021-06-24%20013322.png)

# %% [markdown]
# **2. Inception-B block:**
#  - Use 1xn and nx1 convolution instead of nxn convolution, and also use average pooling. This module mainly deals with feature maps of size 17x17. The structure is as follows:
#  ![Screenshot%202021-06-24%20013411.png](attachment:Screenshot%202021-06-24%20013411.png)

# %% [markdown]
# **3. Inception-C block:**
# - This module mainly deals with feature maps of size 8x8. The structure is as follows:
#      ![Screenshot%202021-06-24%20013510.png](attachment:Screenshot%202021-06-24%20013510.png)

# %% [markdown]
# - When the feature map is reduced from 35x35 to 17x17, and then to 8x8, instead of using a simple pooling layer, two Reduction structures are used. The specific structure is as follows:
# ![Screenshot%202021-06-24%20013549.png](attachment:Screenshot%202021-06-24%20013549.png)

# %% [markdown]
# ![Screenshot%202021-06-24%20013616.png](attachment:Screenshot%202021-06-24%20013616.png)

# %% [markdown]
# ![Screenshot%202021-06-24%20013702.png](attachment:Screenshot%202021-06-24%20013702.png)
