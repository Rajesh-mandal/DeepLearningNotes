# %% [markdown]
# - Inception-ResNet v1 and v2. Inspired by the performance of the ResNet, a hybrid inception module was proposed. ... Inception-ResNet v1 has a computational cost that is similar to that of Inception v3. Inception-ResNet v2 has a computational cost that is similar to that of Inception v4.
#
# - There are further two sub-versions of Inception-ResNet, namely v1 and v2. Inception-ResNet v2 has higher accuracy and computational cost as compared to Inception-ResNet v1

# %% [markdown]
# # inception resnet v1
# The three basic modules are as follows:
# ![Screenshot%202021-06-24%20014919.png](attachment:Screenshot%202021-06-24%20014919.png)
# - The Reduction-A module of Inception-ResNet v1 is consistent with that of Inception v4,
#
# - The Reduction-B module is as follows:

# %% [markdown]
# ![Screenshot%202021-06-24%20015007.png](attachment:Screenshot%202021-06-24%20015007.png)

# %% [markdown]
# The complete architecture is as follows:
#     ![Screenshot%202021-06-24%20015058.png](attachment:Screenshot%202021-06-24%20015058.png)

# %% [markdown]
# # inception_resnet_v2
# - Inception-ResNet-v2 is a convolutional neural architecture that builds on the Inception family of architectures but incorporates residual connections (replacing the filter concatenation stage of the Inception architecture).
#
# - The three basic modules are as follows:
# ![Screenshot%202021-06-24%20015213.png](attachment:Screenshot%202021-06-24%20015213.png)
# The Reduction-A module of Inception-ResNet v2 is also consistent with that of Inception v4, and the Reduction-B module is as follows:

# %% [markdown]
# ![Screenshot%202021-06-24%20015246.png](attachment:Screenshot%202021-06-24%20015246.png)

# %% [markdown]
# - The overall architecture of Inception-Resnet v2 is consistent with v1, and the specific structure of Stem is different. The structure of Stem of Inception-Resnet v2 is consistent with that of Inception v4, as shown in the following figure:
# ![Screenshot%202021-06-24%20015334.png](attachment:Screenshot%202021-06-24%20015334.png)
